# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1

plt.plot(x,y)

plt.xlabel('x label')
plt.ylabel('y label')
plt.title('X vs Y')
# Out:
# Text(0.5, 1.0, 'X vs Y')

# %%
plt.plot(x,z)

plt.xlabel('x label')
plt.ylabel('z label')
plt.plot(x,z)

# %%
# combine (x, y) and (x, z) into 1 chart

plt.plot(x,y, label='X vs Y')
plt.plot(x,z, label='X vs Z')

plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

plt.rcParams["figure.figsize"] = (15,5)    # adjust the size to 15 * 5 inch

fig, [ax1,ax2]=plt.subplots(1,2)

ax1.plot(x,y)
ax1.set_title('X vs Y')
ax1.set_xlabel('X label')
ax1.set_ylabel('Y label')


ax2.plot(x,z)
ax2.set_title('X vs Z')
ax2.set_xlabel('X label')
ax2.set_ylabel('Z label')


plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
plt.rcParams["figure.figsize"] = (15,5)    # adjust the size to 15 * 5 inch

fig, [ax1,ax2]=plt.subplots(1,2)

ax1.plot(x,y)
ax1.set_title('X vs Y',fontsize=20)
ax1.set_xlabel('X value',fontsize=15)
ax1.set_ylabel('Y value',fontsize=15)


ax2.plot(x,z)
ax2.set_title('X vs Z',fontsize=40)
ax2.set_xlabel('X value',fontsize='large')
ax2.set_ylabel('Z value',fontsize='small')


plt.show()

# %%
## Another method, use params

import matplotlib.pylab as pylab


fig, [ax1,ax2]=plt.subplots(1,2)

ax1.plot(x,y)
ax1.set_title('X vs Y')
ax1.set_xlabel('X value')
ax1.set_ylabel('Y value')



ax2.plot(x,z)
ax2.set_title('X vs Z')
ax2.set_xlabel('X value')
ax2.set_ylabel('Z value')


params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
          'axes.titlesize':60,
          'axes.titlecolor':'pink',
          'axes.labelsize': 10,
          'axes.labelcolor':'blue',
         'xtick.labelsize':'small',
         'ytick.labelsize':'small'}

pylab.rcParams.update(params)

plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
from math import e


x = np.arange(0,100)
y1 = x**2
y2= e**x


fig,[ax1,ax2]=plt.subplots(1,2)
ax1.plot(x,y1)


ax2.plot(x,y2)
ax2.set_xscale('log')
ax2.set_yscale('log')


plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
from math import e


x = np.arange(0,100)
y1 = x**2
y2= e**x


fig,[ax1,ax2]=plt.subplots(1,2)
ax1.plot(x,y1,label='y= x**2')   # Problem: didn't show legend


ax2.plot(x,y2,label='y= e**x')
ax2.set_xscale('log')
ax2.set_yscale('log')

plt.legend()

plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit=pd.read_csv('../Fitbit2.csv')
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
f,ax=plot.subplot(1,2,figsize=(12,4))

plt.sca(ax[0])

weekday_steps.plot(kind='line',linewidth=2)

plt.ylabel('Median number of steps')
plt.xlabel('Months')
plt.title('Medain steps walked by month')
plt.xticks(range(1,13), ['January', 'February', 'March','April','May','June','July','August','September','October','November','December'])



plt.sca(ax[1])

weekday_steps=fitbit['Steps'].groupby(fitbit['Work_or_Weekend']).median().sort_values()

weekday_steps.plot(kind='bar',alpha=0.5)
plt.ylabel
plt.xlabel
plt.title
plt.xticks(range(2),['Weekend','Workdays'].rotation=90)
# Out:
#   File "<ipython-input-12-af651fde4f13>", line 22
#     plt.xticks(range(2),['Weekend','Workdays'].rotation=90)
#                        ^
# SyntaxError: keyword can't be an expression

# %%
# MEDIAN STEPS BY MONTH_ENCODED

# Filtering
months=fitbit.groupby('Months_encoded')['Steps'].median().reset_index()

# Visualising
plt.figure(figsize=(18,4))
plt.bar(months['Months_encoded'], months['Steps'])
plt.xticks(np.arange(1,13), ['January', 'February', 'March','April','May','June','July','August','September','October','November','December'])
plt.xlabel('Month')
plt.ylabel('Median Steps of the month ')
plt.title('Median steps by month',fontsize=20,color='blue')

# Saving
plt.savefig('../figures/Median steps by month.png')

# %%
# MEDIAN STEPS BY WORK_OR_WEEKEND


# Filtering
weekend=fitbit.groupby('Work_or_Weekend')['Steps'].median().reset_index()
weekend['Work_or_Weekend'].replace([0,1],['Work','Weekend'],inplace=True)
labels=weekend['Work_or_Weekend'].to_list()
sizes=weekend['Steps'].to_list()


# Visualising
plt.figure(figsize=(20,5))
plt.pie(sizes,labels=labels,autopct='%1.1f%%',explode=(0,0.1),colors=['gold','yellowgreen'],startangle=90, shadow=True)
plt.title('Steps by weekend',fontsize=20,color='blue')



# Saving
plt.savefig('../figures/Steps by weekend.png')


plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
fitbit.head()

# %%
x_list=['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']

for i in x_list:
    x=fitbit[i].to_list()
    y=fitbit['Steps'].to_list()
    
    plt.scatter(x,y)
    plt.xlabel(i)
    plt.ylabel('Steps')
    plt.title(i+' vs Steps',fontsize=20,color='blue')
       
    # Saving
    plt.savefig('../figures/{} vs Steps.png'.format(i))
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic=pd.read_csv('../titanic.csv')
titanic
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# Survived                     int64
# Pclass                       int64
# Name                        object
# Sex                         object
# Age                        float64
# Siblings/Spouses Aboard      int64
# Parents/Children Aboard      int64
# Fare                       float64
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES

titanic.select_dtypes('number').columns
# Out:
# Index(['Survived', 'Pclass', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare'],
#       dtype='object')

# %%
# CATEGORICAL VARIABLES

titanic.select_dtypes('object').columns
# Out:
# Index(['Name', 'Sex'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')

plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
titanic['Age'].plot(kind='box')

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
data = titanic['Age']

fig, axs = plt.subplots(1, 3, sharey=True, tight_layout=True)

axs[0].hist(data, bins=10)
axs[1].hist(data, bins=20)
axs[2].hist(data, bins=50)


# ax.set_title('Age distribution by bins')
# ax.set_xlabel('Age')
# ax.set_ylabel('Frequency')

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
When the bins get bigger numbers, the frequency is not less visible
"""
# Out:
# '\nWhen the bins get bigger numbers, the frequency is not less visible\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.distplot(titanic['Age'])

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib


colors=['lightblue','pink']

values=titanic['Sex'].value_counts().values
labels=titanic['Sex'].value_counts().index

plt.pie(values,labels=labels,autopct=lambda p : '{:.2f}%  ({:,.0f})'.format(p,p * sum(values)/100),explode=(0,0.1),colors=colors)
plt.legend(titanic.Sex)
plt.title('Gender distribution',color='white')
plt.show()

# %%
# Method 2 - seaborn

gender=titanic['Sex'].value_counts().reset_index()
data=gender.rename(columns={'index':'Gender','Sex':'Number of poeple'})



 # there is no pie plot in seaborn
 # unable to give a title name :(

sns.barplot(data=data,x='Number of poeple',y='Gender',palette='Spectral',hue="Gender")

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
